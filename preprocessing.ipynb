# %% [markdown]
# <a href="https://colab.research.google.com/github/selviij/-preprocessing-dengan-python/blob/main/preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('customer_churn_data.csv')
data.head()
# Out:
#    CustomerID  Age  Gender  Tenure  MonthlyCharges    ContractType  \
# 0           1   49    Male       4           88.35  Month-to-Month
# 1           2   43    Male       0           36.67  Month-to-Month
# 2           3   51  Female       2           63.79  Month-to-Month
# 3           4   60  Female       8          102.34        One-Year
# 4           5   42    Male      32           69.01  Month-to-Month
#
#   InternetService  TotalCharges TechSupport Churn
# 0     Fiber Optic        353.40         Yes   Yes
# 1     Fiber Optic          0.00         Yes   Yes
# 2     Fiber Optic        127.58          No   Yes
# 3             DSL        818.72         Yes   Yes
# 4             NaN       2208.32          No   Yes

# %%
data.shape
# Out:
# (1000, 10)

# %%
data.columns
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'Tenure', 'MonthlyCharges',
#        'ContractType', 'InternetService', 'TotalCharges', 'TechSupport',
#        'Churn'],
#       dtype='object')

# %%
dataset.isnull().sum()
# Out:
# CustomerID           0
# Age                  0
# Gender               0
# Tenure               0
# MonthlyCharges       0
# ContractType         0
# InternetService    297
# TotalCharges         0
# TechSupport          0
# Churn                0
# dtype: int64

# %%
dataset = dataset.dropna()

# %%
dataset
# Out:
#      CustomerID  Age  Gender  Tenure  MonthlyCharges    ContractType  \
# 0             1   49    Male       4           88.35  Month-to-Month
# 1             2   43    Male       0           36.67  Month-to-Month
# 2             3   51  Female       2           63.79  Month-to-Month
# 3             4   60  Female       8          102.34        One-Year
# 5             6   42  Female      16          119.75        Two-Year
# ..          ...  ...     ...     ...             ...             ...
# 991         992   24    Male      32           81.93  Month-to-Month
# 993         994   38    Male       4          102.27        One-Year
# 994         995   34  Female       1           78.63  Month-to-Month
# 995         996   42    Male      41           37.14  Month-to-Month
# 997         998   51  Female      15          111.72  Month-to-Month
#
#     InternetService  TotalCharges TechSupport Churn
# 0       Fiber Optic        353.40         Yes   Yes
# ...

# %%
dataset.isnull().sum()
# Out:
# CustomerID         0
# Age                0
# Gender             0
# Tenure             0
# MonthlyCharges     0
# ContractType       0
# InternetService    0
# TotalCharges       0
# TechSupport        0
# Churn              0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

lb = LabelEncoder()
data['Tenure'] = lb.fit_transform(data['Tenure'])
data
# Out:
#      CustomerID  Age  Gender  Tenure  MonthlyCharges    ContractType  \
# 0             1   49    Male       4           88.35  Month-to-Month
# 1             2   43    Male       0           36.67  Month-to-Month
# 2             3   51  Female       2           63.79  Month-to-Month
# 3             4   60  Female       8          102.34        One-Year
# 4             5   42    Male      32           69.01  Month-to-Month
# ..          ...  ...     ...     ...             ...             ...
# 995         996   42    Male      41           37.14  Month-to-Month
# 996         997   62    Male       9           80.93  Month-to-Month
# 997         998   51  Female      15          111.72  Month-to-Month
# 998         999   39    Male      67           65.67        One-Year
# 999        1000   50    Male       1           56.67  Month-to-Month
#
#     InternetService  TotalCharges TechSupport Churn
# 0       Fiber Optic        353.40         Yes   Yes
# ...

# %%
data.describe().T
# Out:
#                  count        mean          std   min       25%     50%  \
# CustomerID      1000.0   500.50000   288.819436   1.0  250.7500  500.50
# Age             1000.0    44.67400     9.797741  12.0   38.0000   45.00
# Tenure          1000.0    18.75800    18.146921   0.0    5.0000   13.00
# MonthlyCharges  1000.0    74.39129    25.712083  30.0   52.3575   74.06
# TotalCharges    1000.0  1404.36406  1571.755048   0.0  345.2175  872.87
#
#                       75%       max
# CustomerID       750.2500   1000.00
# Age               51.0000     83.00
# Tenure            26.0000     86.00
# MonthlyCharges    96.1025    119.96
# TotalCharges    1900.1750  12416.25

# %%
data['Age_mean'] = data['Age'].mean()
data['Tenure_mean'] = data['Tenure'].mean()
data['MonthlyCharges_mean'] = data['MonthlyCharges'].mean()
data['TotalCharges_mean'] = data['TotalCharges'].mean()

sns.pairplot(data, vars=['Age_mean', 'Tenure_mean', 'MonthlyCharges_mean', 'TotalCharges_mean'], hue='CustomerID')

plt.ioff
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
sns.countplot(data['CustomerID'])
plt.ioff()
